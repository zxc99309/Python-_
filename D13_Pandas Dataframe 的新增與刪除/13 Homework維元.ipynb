# %% [markdown]
# # [作業目標]
#
#
# 1. 請接下列資料依照指定規則做合併：
#
# ```
# - 依照 fruit 欄位做合併
# - 依照 index 索引做合併
# ```
#
# 2. [簡答題] 承上題，請問為什麼依照 merge 合併後有些資料不見了？
#
# 3. [簡答題] 承上題，請問為什麼依照 index 合併會發生錯誤？請用程式解決。

# %% [markdown]
# # 作業

# %%
# 記得先 Import 正確的套件

'''
Your Code
'''
import numpy as np
import pandas as pd

# %% [markdown]
# ### 1. 請接下列資料依照指定規則做合併：
#
# ```
# - 依照 fruit 欄位做合併
# - 依照 index 索引做合併
# ```

# %%
df1 = pd.DataFrame({
    'fruit': ['apple', 'banana', 'orange'] * 3,
    'weight': ['high', 'medium', 'low'] * 3,
    'price': np.random.randint(0, 15, 9)
})

df2 = pd.DataFrame({
    'fruit': ['apple', 'orange', 'pine'] * 2,
    'weight': ['high', 'low'] * 3,
    'price': np.random.randint(0, 15, 6)
})
print(df1)
print(df2)
# Out:
#     fruit  weight  price
# 0   apple    high      3
# 1  banana  medium      5
# 2  orange     low     13
# 3   apple    high      7
# 4  banana  medium      8
# 5  orange     low     14
# 6   apple    high      0
# 7  banana  medium      4
# 8  orange     low     11
#     fruit weight  price
# 0   apple   high      3
# 1  orange    low     12
# 2    pine   high      6
# 3   apple    low      2
# 4  orange   high      0
# 5    pine    low     12

# %%
pd.merge(df1, df2, on = 'fruit')
# Out:
#      fruit weight_x  price_x weight_y  price_y
# 0    apple     high        3     high        3
# 1    apple     high        3      low        2
# 2    apple     high        7     high        3
# 3    apple     high        7      low        2
# 4    apple     high        0     high        3
# 5    apple     high        0      low        2
# 6   orange      low       13      low       12
# 7   orange      low       13     high        0
# 8   orange      low       14      low       12
# 9   orange      low       14     high        0
# 10  orange      low       11      low       12
# 11  orange      low       11     high        0

# %%
# - 依照 index 索引做合併

'''
Your Code
'''
df1.join(df2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-4acf79b137db> in <module>
#       4 Your Code
#       5 '''
# ----> 6 df1.join(df2)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    7206         5  K5  A5  NaN
#    7207         """
# -> 7208         return self._join_compat(
#    7209             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    7210         )
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    7222
#    7223         if isinstance(other, DataFrame):
# -> 7224             return merge(
#    7225                 self,
#    7226                 other,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      86         validate=validate,
#      87     )
# ---> 88     return op.get_result()
#      89
#      90
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     646         lsuf, rsuf = self.suffixes
#     647
# --> 648         llabels, rlabels = _items_overlap_with_suffix(
#     649             ldata.items, lsuf, rdata.items, rsuf
#     650         )
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _items_overlap_with_suffix(left, lsuffix, right, rsuffix)
#    2022
#    2023     if not lsuffix and not rsuffix:
# -> 2024         raise ValueError(
#    2025             "columns overlap but no suffix specified: "
#    2026             "{rename}".format(rename=to_rename)
#
# ValueError: columns overlap but no suffix specified: Index(['fruit', 'weight', 'price'], dtype='object')

# %% [markdown]
# ### 2. [簡答題] 承上題，請問為什麼依照 merge 合併後有些資料不見了？

# %%
'''
Your Code
'''

# %% [markdown]
# ### 3. [簡答題] 承上題，請問為什麼依照 index 合併會發生錯誤？請用程式解決。

# %%
'''
Your Code
'''
pd.merge(df1, df2, how = 'left', left_index = True, right_index = True)
# Out:
#   fruit_x weight_x  price_x fruit_y weight_y  price_y
# 0   apple     high        3   apple     high      3.0
# 1  banana   medium        5  orange      low     12.0
# 2  orange      low       13    pine     high      6.0
# 3   apple     high        7   apple      low      2.0
# 4  banana   medium        8  orange     high      0.0
# 5  orange      low       14    pine      low     12.0
# 6   apple     high        0     NaN      NaN      NaN
# 7  banana   medium        4     NaN      NaN      NaN
# 8  orange      low       11     NaN      NaN      NaN

# %%
# Out:
#   fruit_df1 weight_df1  price_df1 fruit_df2 weight_df2  price_df2
# 0     apple       high          3     apple       high        3.0
# 1    banana     medium          6    orange        low        2.0
# 2    orange        low          0      pine       high       11.0
# 3     apple       high          5     apple        low        3.0
# 4    banana     medium          1    orange       high       13.0
# 5    orange        low          2      pine        low        8.0
# 6     apple       high         12       NaN        NaN        NaN
# 7    banana     medium         11       NaN        NaN        NaN
# 8    orange        low          7       NaN        NaN        NaN
